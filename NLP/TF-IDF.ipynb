# %%
documents = [
    "I love machine learning",
    "Machine learning is amazing",
    "I love deep learning",
    "Deep learning uses neural networks"
]

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

corpus = []

for doc in documents:
    review = re.sub('[^a-zA-Z]', ' ', doc)
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) 
              for word in review 
              if word not in stop_words]
    
    review = ' '.join(review)
    corpus.append(review)

print(corpus)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kabir\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kabir\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kabir\AppData\Roaming\nltk_data...
# ['love machine learning', 'machine learning amazing', 'love deep learning', 'deep learning us neural network']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X = tfidf.fit_transform(corpus)

# %%
print(tfidf.get_feature_names_out())
# Out:
# ['amazing' 'deep' 'learning' 'love' 'machine' 'network' 'neural' 'us']

# %%
X[0].toarray()
# Out:
# array([[0.        , 0.        , 0.42389674, 0.64043405, 0.64043405,
#         0.        , 0.        , 0.        ]])

# %%
tfidf_bigram = TfidfVectorizer(ngram_range=(1,2))
X2 = tfidf_bigram.fit_transform(corpus)

print(tfidf_bigram.get_feature_names_out())
# Out:
# ['amazing' 'deep' 'deep learning' 'learning' 'learning amazing'
#  'learning us' 'love' 'love deep' 'love machine' 'machine'
#  'machine learning' 'network' 'neural' 'neural network' 'us' 'us neural']
